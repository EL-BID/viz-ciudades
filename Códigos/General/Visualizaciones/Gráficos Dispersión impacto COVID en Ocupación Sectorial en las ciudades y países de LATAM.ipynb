# %%
# !pip install plotly_express
import plotly_express as px

# %%
#Intensidad del National Share por Sector y País
px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='ns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-85886b69d8b8> in <module>()
#       1 #Intensidad del National Share por Sector y País
# ----> 2 px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='ns')
#
# NameError: name 'df' is not defined

# %%
df= pd.read_excel('/content/drive/Shareddrives/BID/Ciudades/Metadatos/reshape3.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3bd70665d6ad> in <module>()
# ----> 1 df= pd.read_excel('/content/drive/Shareddrives/BID/Ciudades/Metadatos/reshape3.xlsx')
#
# NameError: name 'pd' is not defined

# %%
#Intensidad del National Share por Sector y País
px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='ns')

# %%
px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='ns_labor')

# %%
px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='im_labor')

# %%
px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='rs_labor')

# %%
px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='c_labor')

# %%
df['variación'] = (df['Total2']/df['Total1'])-1
df

# %%
px.scatter(data_frame=df, x='País', y='Sector_renombrado', color='variación')
