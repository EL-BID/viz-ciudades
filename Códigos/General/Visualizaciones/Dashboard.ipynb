# %% [markdown]
# #*Preconfiguración*

# %%
# !pip install plotly_express
import plotly_express as px
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# !ls

# %% [markdown]
# #*Carga de datos*

# %%
path1 = '/content/drive/Shareddrives/BID/Ciudades/Metadatos/Consolidado micro_meta-20.01.22.xlsx'
df1_consolidados = pd.read_excel(path1)
df1_consolidados

# %%
df= pd.read_excel('/content/drive/Shareddrives/BID/Ciudades/Metadatos/reshape3.xlsx')
df

# %% [markdown]
# #*Limpieza de datos*

# %% [markdown]
# #*Compomentes del Dashboard*

# %% [markdown]
# Intensidad de impacto-recuperación de ocupación por sectores PostCovid

# %% [markdown]
# Ranking de recuperación + Ranking de Rezago

# %% [markdown]
# Desempeño en recuperación: velocímetro: parcial, mitad, recuperación total

# %% [markdown]
# Transición sectores con gráficos araña

# %% [markdown]
# #*Código General para dashboard*
