# %% [markdown]
# ##0. Preconfiguración

# %%
from google.colab import drive
drive.mount('/content/drive/')
# !ls
# Out:
# Mounted at /content/drive/
# drive  sample_data

# %%
import pandas as pd
import numpy as np

# %%
# %cd'/content/drive/My Drive/BID Ciudades'
# !ls
# Out:
# /content/drive/My Drive/BID Ciudades
# 'Balance Noviembre Fuentes, Tipos y Alternativas Datos Ciudades.gslides'
#  Códigos
# 'Cuadros ShiftShare Mx y Arg con capitales y áreas metropolitanas de capitales.xlsx'
# 'Diccionarios Ciudades LATAM.xlsx'
# 'Diccionario Sectores CIIU LATAM.xlsx'
# 'Google Trends'
#  Inventario_Datos_Países_Ciudades_5nov2021.xlsx
#  MicroDatos
# 'Shift-Share Mex y Argentina.ppt'

# %% [markdown]
# ##1. Carga de datos países del caribe

# %% [markdown]
# Barbados

# %%
path = '/content/drive/MyDrive/BID Ciudades/Google Trends/Barbados/EmpleoBarbados.csv'
df_barbados = pd.read_csv(path)
df_barbados
# Out:
#            Categoría: Todas las categorías
# Semana                  Empleo: (Barbados)
# 2016-12-04                              54
# 2016-12-11                              36
# 2016-12-18                              40
# 2016-12-25                              30
# ...                                    ...
# 2021-10-24                              26
# 2021-10-31                              48
# 2021-11-07                              22
# 2021-11-14                              35
# 2021-11-21                              39
#
# [261 rows x 1 columns]

# %%
/content/drive/MyDrive/BID Ciudades/Google Trends/Barbados/EmpleoBarbados.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Barbados/ReclutamientoBarbados.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Barbados/SubregionesEmpleoBarbados.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Barbados/SubregionesReclutamientoBarbados.csv

# %% [markdown]
# Bahamas

# %%
path = '/content/drive/MyDrive/BID Ciudades/Google Trends/Bahamas/EmpleoBahamas.csv'
df_bahamas = pd.read_csv(path)
df_bahamas
# Out:
#            Categoría: Todas las categorías
# Semana                   Empleo: (Bahamas)
# 2016-12-04                              51
# 2016-12-11                              71
# 2016-12-18                              15
# 2016-12-25                              23
# ...                                    ...
# 2021-10-24                              71
# 2021-10-31                              57
# 2021-11-07                              60
# 2021-11-14                              70
# 2021-11-21                              42
#
# [261 rows x 1 columns]

# %%
/content/drive/MyDrive/BID Ciudades/Google Trends/Bahamas/EmpleoBahamas.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Bahamas/ReclutamientoBahamas.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Bahamas/SubregionesEmpleoBahamas.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Bahamas/SubregionesReclutamientoBahamas.csv

# %% [markdown]
# Jamaica

# %%
path = '/content/drive/MyDrive/BID Ciudades/Google Trends/Jamaica/EmpleoJamaica.csv'
df_jamaica = pd.read_csv(path)
df_jamaica
# Out:
#            Categoría: Todas las categorías
# Semana                   Empleo: (Jamaica)
# 2016-12-04                              22
# 2016-12-11                               6
# 2016-12-18                              26
# 2016-12-25                               7
# ...                                    ...
# 2021-10-24                              35
# 2021-10-31                              12
# 2021-11-07                              20
# 2021-11-14                              15
# 2021-11-21                              22
#
# [261 rows x 1 columns]

# %%
/content/drive/MyDrive/BID Ciudades/Google Trends/Jamaica/EmpleoJamaica.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Jamaica/ReclutamientoJamaica.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Jamaica/SubregionesEmpleoJamaica.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Jamaica/SubregionesReclutamientoJamaica.csv

# %% [markdown]
# Surinam

# %%
path = '/content/drive/MyDrive/BID Ciudades/Google Trends/Surinam/EmpleoSurinam.csv'
df_surinam = pd.read_csv(path)
df_surinam
# Out:
#            Categoría: Todas las categorías
# Semana                   Empleo: (Surinam)
# 2016-12-04                              48
# 2016-12-11                              26
# 2016-12-18                              13
# 2016-12-25                              13
# ...                                    ...
# 2021-10-24                              47
# 2021-10-31                              35
# 2021-11-07                              47
# 2021-11-14                              23
# 2021-11-21                              23
#
# [261 rows x 1 columns]

# %%
/content/drive/MyDrive/BID Ciudades/Google Trends/Surinam/EmpleoSurinam.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Surinam/ReclutamientoSurinam.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Surinam/SubregionesEmpleoSurinam.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Surinam/SubregionesReclutamientoSurinam.csv

# %% [markdown]
# Guayana

# %%
path = '/content/drive/MyDrive/BID Ciudades/Google Trends/Guyana/EmpleoGuyana.csv'
df_guyana = pd.read_csv(path)
df_guyana
# Out:
#            Categoría: Todas las categorías
# Semana                    Empleo: (Guyana)
# 2016-12-04                               0
# 2016-12-11                               0
# 2016-12-18                               0
# 2016-12-25                               0
# ...                                    ...
# 2021-10-24                              20
# 2021-10-31                               0
# 2021-11-07                               0
# 2021-11-14                              20
# 2021-11-21                               0
#
# [261 rows x 1 columns]

# %%
/content/drive/MyDrive/BID Ciudades/Google Trends/Guyana/EmpleoGuyana.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Guyana/ReclutamientoGuyana.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Guyana/SubregionEmpleoGuyana.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Guyana/SubregionesReclutamientoGuyana.csv

# %% [markdown]
# Trinidad y Tobago

# %%
path = '/content/drive/MyDrive/BID Ciudades/Google Trends/Trinidad y Tobago/EmpleoTrinidadYTobago.csv'
df_trinitobago = pd.read_csv(path)
df_trinitobago
# Out:
#            Categoría: Todas las categorías
# Semana         Empleo: (Trinidad y Tobago)
# 2016-12-04                              30
# 2016-12-11                              66
# 2016-12-18                              12
# 2016-12-25                              46
# ...                                    ...
# 2021-10-24                              30
# 2021-10-31                              64
# 2021-11-07                              31
# 2021-11-14                              34
# 2021-11-21                              17
#
# [261 rows x 1 columns]

# %%
/content/drive/MyDrive/BID Ciudades/Google Trends/Trinidad y Tobago/EmpleoTrinidadYTobago.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Trinidad y Tobago/ReclutamientoTrinidadYTobago.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Trinidad y Tobago/SubregionesEmpleoTrinidadYTobago.csv

/content/drive/MyDrive/BID Ciudades/Google Trends/Trinidad y Tobago/SubregionesReclutamientoTrinidadYTobago.csv

# %% [markdown]
# ##Visualización Índice Empleo de Google para Países Caribe

# %%
#Concatenando todos los países del caribe

# %%
base_conjunta_caribe = pd.concat([df_bahamas, df_barbados, df_guyana, df_jamaica, df_surinam, df_trinitobago], axis=1)
base_conjunta_caribe2 = base_conjunta_caribe.reset_index()
base_conjunta_caribe2
# Out:
#           index  ... Categoría: Todas las categorías
# 0        Semana  ...     Empleo: (Trinidad y Tobago)
# 1    2016-12-04  ...                              30
# 2    2016-12-11  ...                              66
# 3    2016-12-18  ...                              12
# 4    2016-12-25  ...                              46
# ..          ...  ...                             ...
# 256  2021-10-24  ...                              30
# 257  2021-10-31  ...                              64
# 258  2021-11-07  ...                              31
# 259  2021-11-14  ...                              34
# 260  2021-11-21  ...                              17
#
# [261 rows x 7 columns]

# %%
base_conjunta_caribe_depurada = base_conjunta_caribe2.drop(columns=[1])
base_conjunta_caribe_depurada
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-d92f8813d606> in <module>()
# ----> 1 base_conjunta_caribe_depurada = base_conjunta_caribe2.drop(columns=[1])
#       2 base_conjunta_caribe_depurada
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
# !pip install plotly_express
import plotly_express as px

# %%
px.scatter(data_frame=base_conjunta_caribe, x='Categoría: Todas las categorías', y='Categoría: Todas las categorías')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a73c6fb0-05b8-4f78-ad9d-11dede460a38" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a73c6fb0-05b8-4f78-ad9d-11dede460a38")) {
#                     Plotly.newPlot(
#                         'a73c6fb0-05b8-4f78-ad9d-11dede460a38',
# ...
