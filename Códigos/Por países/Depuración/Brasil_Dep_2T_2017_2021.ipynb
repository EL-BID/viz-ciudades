# %% [markdown]
# Fuente Pesquisa Nacional por Amostra de Domicílios Contínua https://www.ibge.gov.br/estatisticas/sociais/trabalho/9173-pesquisa-nacional-por-amostra-de-domicilios-continua-trimestral.html?=&t=resultados

# %% [markdown]
# Variables

# %% [markdown]
# A partir de abril de 2016
# 1 – Pessoas na força de trabalho
# (v2009>=014 e v4009≠ branco)
# ou
# (
# v2009>=014 e V4009=branco e
# ((V4071=1 e 01 <= V4072A <= 08 e V4077=1)
#  ou
# (((V4071=1 e V4072A=09) ou V4071=2) and V4073=1 e V4074A=01 e (V4075A=1 ou (V4075A=2
# e V4075A1 = (01 ou 02 ou 03))) e V4077=1))
# )

# %% [markdown]
# VD4002 – Condição de ocupação na semana de referência para pessoas de 14 anos ou mais de
# idade
# A partir janeiro de 2012 até setembro de 2015
# 1 – Pessoas ocupadas
# V2009 >= 014 e V4009 ≠ branco

# %% [markdown]
# A partir de abril de 2016
# 1 – Pessoas ocupadas
# V2009 >= 014 e V4009 ≠ branco

# %% [markdown]
# VD4010 – Grupamentos de atividade principal do empreendimento do trabalho principal da
# semana de referência para pessoas de 14 anos ou mais de idade. A partir de outubro de 2015
# 01 – Agricultura, pecuária, produção florestal, pesca e aquicultura
# V2009 >= 014 e V4009 ≠ branco e 01101<=V4013<=03002
# 02 – Indústria
# V2009 >= 014 e V4009 ≠ branco e 05000<=V4013<=39000
# 03 – Construção
# V2009 >= 014 e V4009 ≠ branco e 41000<=V4013<=43000
# 04 – Comércio, reparação de veículos automotores e motocicletas
# V2009 >= 014 e V4009 ≠ branco e 45010<=V4013<=48100
# 05 – Transporte, armazenagem e correio
# V2009 >= 014 e V4009 ≠ branco e 49010<=V4013<=53002
# 06 – Alojamento e alimentação
# V2009 >= 014 e V4009 ≠ branco e 55000<=V4013<=56020
# 07 – Informação, comunicação e atividades financeiras, imobiliárias, profissionais e administrativas
# V2009 >= 014 e V4009 ≠ branco e 58000<=V4013<=82009
# 08 – Administração pública, defesa e seguridade social
# V2009 >= 014 e V4009 ≠ branco e 84011<=V4013<=84020
# 09 – Educação, saúde humana e serviços sociais
# V2009 >= 014 e V4009 ≠ branco e 85011<=V4013<=88000
# 10 – Outros serviços
# V2009 >= 014 e V4009 ≠ branco e (90000<=V4013<=96090 ou V4013=99000)
# 11 – Serviços domésticos
# V2009 >= 014 e V4009 ≠ branco e V4013=97000
# 12 – Atividades mal definidas
# V2009 >= 014 e V4009 ≠ branco e V4013=00000

# %% [markdown]
# VD4015 – Tipo de remuneração habitualmente recebida no trabalho principal para pessoas de 14
# anos ou mais de idade. A partir de outubro de 2015
# 1 – Remuneração em dinheiro, produtos ou mercadorias no trabalho principal
# V2009 >= 014 e V4009 ≠ branco e (V40331 = 1 ou V40332 = 2)

# %% [markdown]
# ##Preconfiguración

# %%
from google.colab import drive
drive.mount('/content/drive/')
# !ls
# Out:
# Mounted at /content/drive/
# drive  sample_data

# %%
# %cd'/content/drive/My Drive/BID Ciudades/MicroDatos/Brasil'
# !ls
# Out:
# /content/drive/My Drive/BID Ciudades/MicroDatos/Brasil
# 'BRASIL MICRODATO Dicionario_e_input_20210617.zip'   PNADC_022020.txt
# 'BRASIL MICRODATO PNADC_022021.zip'		     PNADC_022020.zip
#  PNADC_012017_20190729.zip			     PNADC_022021.txt
#  PNADC_012018_20190729.zip			     PNADC_022021.zip
#  PNADC_012019_20190729.zip			     PNADC_032017_20190729.zip
#  PNADC_012020.zip				     PNADC_032018_20190729.zip
#  PNADC_012021.zip				     PNADC_032019.zip
#  PNADC_022017_20190729.txt			     PNADC_032020_20210208.zip
#  PNADC_022017_20190729.zip			     PNADC_042017_20190729.zip
#  PNADC_022018_20190729.txt			     PNADC_042018_20190729.zip
#  PNADC_022018_20190729.zip			     PNADC_042019.zip
#  PNADC_022019.txt				     PNADC_042020.zip
#  PNADC_022019.zip

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.5'

# %% [markdown]
# ##Carga de Datos, que vienen en txt

# %% [markdown]
# 2T2017

# %%
df2T2017 = open ('/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022017_20190729.txt', 'r')

# %%
df2T2017
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022017_20190729.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# 2T2018

# %%
df2T2018 = open ('/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022018_20190729.txt')

# %%
df2T2018
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022018_20190729.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# 2T2019

# %%
df2T2019 = open ('/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022019.txt')

# %%
df2T2019
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022019.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# 2T2020

# %%
df2T2020 = open ('/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022020.txt')

# %%
df2T2020
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022020.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# 2T2021

# %%
df2T2021 = open ('/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022021.txt')

# %%
df2T2021
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/BID Ciudades/MicroDatos/Brasil/PNADC_022021.txt' mode='r' encoding='UTF-8'>
