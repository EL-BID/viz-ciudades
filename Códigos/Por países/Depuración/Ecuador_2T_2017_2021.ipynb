# %% [markdown]
# FUENTE <br>
# https://aplicaciones3.ecuadorencifras.gob.ec/BIINEC-war/index.xhtml;jsessionid=ofoNXl+hj+TCf0vIIQIo6Nvt.undefined

# %% [markdown]
# VARIABLES <br>
# Ocupado, grupo1 <br>
# Sector, rama1 <br>
# Salario, ingrl <br>
# Ciudad, ciudad <br>
# factor expansión, fexp <br>

# %% [markdown]
# ##Preconfiguración

# %%
import pandas as pd
import csv
pd.__version__
# Out:
# '1.1.5'

# %%
from google.colab import drive
drive.mount('/content/drive/')
# !ls
# Out:
# Mounted at /content/drive/
# drive  sample_data

# %%
# %cd'/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador'
# !ls
# Out:
# /content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador
#  032017_bddEnemdu_CVS.zip
# '062017_Base de Datos_CSV.zip'
#  201706_EnemduBDD_15anios.csv
#  201706_EnemduBDD_autopercepcion.csv
#  201706_EnemduBDD_con.csv
#  201706_EnemduBDD_pciudadana_spublicos.sav.csv
#  201706_EnemduBDD_seguridad_ciudadana.csv
#  201706_EnemduBDD_viviendahogar.csv
#  201806_EnemduBDD_15anios.csv
#  201806_EnemduBDD_con.csv
#  201806_EnemduBDD_viviendahogar.csv
#  201906_EnemduBDD_15anios.csv
#  201906_EnemduBDD_con.csv
#  201906_EnemduBDD_viviendahogar.csv
#  201906_Metadatos.xlsx
#  2021_06_Metadatos.xlsx
#  2_BDD_DATOS_ABIERTOS_ENEMDU_2020_09_CSV_RECALCULADO.zip
#  2_BDD_DATOS_ABIERTOS_ENEMDU_2020_12_CSV_RECALCULADO.zip
#  2_BDD_DATOS_ABIERTOS_ENEMDU_2020_IV_TRIMESTRE_CSV_RECALCULADO.zip
#  2_BDD_DATOS_ABIERTOS_ENEMDU_2021_03_CSV_RECALCULADO.zip
#  2_BDD_DATOS_ABIERTOS_ENEMDU_2021_06_CSV.zip
#  2_BDD_DATOS_ABIERTOS_ENEMDU_2021_09_CSV.zip
#  BDD_DATOS_ABIERTOS_ENEMDU_2018_06_CSV.zip
# ...

# %% [markdown]
# ##Carga de datos en CSV

# %% [markdown]
# 2T2017 sin homologar

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/201706_EnemduBDD_15anios.csv'
df2T2017Bruto = pd.read_csv(path, delimiter=';')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (199,200) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2T2017Bruto
# Out:
#        area  ciudad  zona  sector  panelm  ...  pein  menor10  menor15  pobla10  pobla15
# 0         1   10150     1       3     172  ...                                1        1
# 1         1   10150     1       3     172  ...                                1        1
# 2         1   10150     1       3     172  ...                                1        1
# 3         1   10150     1       3     172  ...                                1        1
# 4         1   10150     1       3     172  ...                       1        1
# ...     ...     ...   ...     ...     ...  ...   ...      ...      ...      ...      ...
# 58883     2  900451   999       7     232  ...                                1        1
# 58884     2  900451   999       7     242  ...     1                          1        1
# 58885     2  900451   999       7     242  ...                                1        1
# 58886     2  900451   999       7     242  ...     1                          1        1
# ...

# %%
df2T2017Bruto['empleo'].value_counts()
# Out:
#      30953
# 1    27935
# Name: empleo, dtype: int64

# %%
df2T2017Bruto['grupo1'].value_counts()
# Out:
#       30953
# 9      7404
# 5      5595
# 6      5199
# 7      3104
# 2      2241
# 8      1809
# 3      1248
# 4       897
# 1       336
# 10      102
# Name: grupo1, dtype: int64

# %%
df2T2017Bruto['rama1'].value_counts()
# Out:
#       30953
# 1      9043
# 7      4735
# 3      2781
# 9      1648
# 6      1566
# 8      1449
# 16     1275
# 15     1160
# 19      773
# 17      706
# 20      650
# 14      577
# 13      488
# 10      286
# 2       235
# 11      220
# 18      140
# 5        75
# 4        72
# 12       55
# 21        1
# Name: rama1, dtype: int64

# %%
df2T2017Bruto['rama1'].unique()
# Out:
# array(['7', '6', ' ', '3', '8', '17', '16', '9', '1', '15', '11', '10',
#        '19', '18', '14', '20', '13', '5', '4', '12', '2', '21'],
#       dtype=object)

# %% [markdown]
# 2017 junio homologable

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/Base ENCFT 20171 - 20174.xlsx'
df2017juniohomologable = pd.read_excel(path)
df2017juniohomologable
# Out:
#        TRIMESTRE  PERIODO  ... ESTADO_VIVIENDA  APARIENCIA_VIVIENDA
# 0          20171   201701  ...               3                    4
# 1          20171   201701  ...               3                    5
# 2          20171   201701  ...               3                    5
# 3          20171   201701  ...               3                    4
# 4          20171   201701  ...               3                    4
# ...          ...      ...  ...             ...                  ...
# 25539      20174   201712  ...               3                    5
# 25540      20174   201712  ...               3                    5
# 25541      20174   201712  ...               3                    4
# 25542      20174   201712  ...               3                    5
# 25543      20174   201712  ...               3                    5
#
# [25544 rows x 56 columns]

# %% [markdown]
# 2T2018

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/201806_EnemduBDD_15anios.csv'
df2T2018Bruto = pd.read_csv(path, delimiter=';')
df2T2018Bruto
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (194) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        area  ciudad  conglomerado  ...    id_sector     id_hogar   id_persona
# 0         1   10150           801  ...  10150000801    1,015E+16    1,015E+18
# 1         1   10150           801  ...  10150000801    1,015E+16    1,015E+18
# 2         1   10150           801  ...  10150000801    1,015E+16    1,015E+18
# 3         1   10150           801  ...  10150000801    1,015E+16    1,015E+18
# 4         1   10150           801  ...  10150000801    1,015E+16    1,015E+18
# ...     ...     ...           ...  ...          ...          ...          ...
# 59953     2  900451        901402  ...  9,00452E+11  9,00452E+17  9,00452E+19
# 59954     2  900451        901402  ...  9,00452E+11  9,00452E+17  9,00452E+19
# ...

# %%
df2T2018Bruto['area'].value_counts()
# Out:
# 1    37234
# 2    22724
# Name: area, dtype: int64

# %% [markdown]
# 2T2019

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/201906_EnemduBDD_15anios.csv'
df2T2019Bruto = pd.read_csv(path, delimiter=';')
df2T2019Bruto
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (152) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        area  vivienda  hogar  ...            id_hogar            id_persona  periodo
# 0         1         1      1  ...   10150000801009011   1015000080100901101   201906
# 1         1         1      1  ...   10150000801009011   1015000080100901102   201906
# 2         1         2      1  ...   10150000801009021   1015000080100902101   201906
# 3         1         2      1  ...   10150000801009021   1015000080100902102   201906
# 4         1         3      1  ...   10150000801009031   1015000080100903101   201906
# ...     ...       ...    ...  ...                 ...                   ...      ...
# 60412     2         6      1  ...  900451901402099061  90045190140209906108   201906
# ...

# %% [markdown]
# 2020 septiembre

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/enemdu_persona_2020_09.csv'
df2020septiembreBruto = pd.read_csv(path, delimiter=';')
df2020septiembreBruto
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (102) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        area  ciudad  ...            id_persona  periodo
# 0         1   10150  ...   1015000030200601101   202009
# 1         1   10150  ...   1015000030200601102   202009
# 2         1   10150  ...   1015000030200601103   202009
# 3         1   10150  ...   1015000030200601104   202009
# 4         1   10150  ...   1015000030200602101   202009
# ...     ...     ...  ...                   ...      ...
# 30312     1  240350  ...  24035000360500603104   202009
# 30313     1  240350  ...  24035000360500603105   202009
# 30314     1  240350  ...  24035000360500605101   202009
# 30315     1  240350  ...  24035000360500605102   202009
# 30316     1  240350  ...  24035000360500608101   202009
#
# [30317 rows x 104 columns]

# %%
df2020septiembreBruto['ciudad'].value_counts()
# Out:
# 90150     5168
# 10150     2908
# 180150    2702
# 70150     2476
# 170150    1707
#           ...
# 132050      13
# 130356      12
# 30750        9
# 91350        9
# 80752        8
# Name: ciudad, Length: 364, dtype: int64

# %%
df2020septiembreBruto['ciudad'].unique()
# Out:
# array([ 10150,  10151,  10152,  10159,  10160,  10170,  10350,  10352,
#         10360,  10550,  10559,  10562,  10650,  10850,  10851,  10955,
#         11150,  11151,  11154,  11550,  20150,  20151,  20153,  20159,
#         20250,  20550,  20554,  20650,  20750,  30150,  30151,  30153,
#         30154,  30351,  30352,  30357,  30450,  30452,  30550,  30651,
#         30750,  40150,  40153,  40159,  40251,  40252,  40353,  40450,
#         40452,  40650,  50150,  50159,  50161,  50250,  50350,  50351,
#         50450,  50453,  50456,  50551,  50553,  50554,  50555,  50651,
#         50752,  60150,  60156,  60159,  60160,  60161,  60250,  60350,
#         60354,  60450,  60650,  60651,  60652,  60754,  60950,  70150,
#         70251,  70254,  70255,  70450,  70650,  70651,  70750,  70950,
#         70952,  70954,  70955,  71053,  71056,  71250,  71251,  71354,
#         80150,  80154,  80163,  80253,  80256,  80259,  80352,  80450,
# ...

# %% [markdown]
# 2021 Abril

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/enemdu_persona_2021_04.csv'
df2021abrilBruto = pd.read_csv(path, delimiter=';')
df2021abrilBruto
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (152) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        area  ciudad  ...            id_persona  periodo
# 0         1   10150  ...   1015000080201601101   202104
# 1         1   10150  ...   1015000080201601102   202104
# 2         1   10150  ...   1015000080201601103   202104
# 3         1   10150  ...   1015000080201601104   202104
# 4         1   10150  ...   1015000080201602101   202104
# ...     ...     ...  ...                   ...      ...
# 30409     1  240352  ...  24035200230200106101   202104
# 30410     1  240352  ...  24035200230200106102   202104
# 30411     1  240352  ...  24035200230200106103   202104
# 30412     1  240352  ...  24035200230200107101   202104
# 30413     1  240352  ...  24035200230200107102   202104
#
# [30414 rows x 154 columns]

# %% [markdown]
# 2021 Mayo

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/enemdu_persona_2021_05.csv'
df2021mayoBruto = pd.read_csv(path, delimiter=';')
df2021mayoBruto
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (152) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        area  ciudad  ...            id_persona  periodo
# 0         1   10150  ...   1015000170701801101   202105
# 1         1   10150  ...   1015000170701801102   202105
# 2         1   10150  ...   1015000170701801103   202105
# 3         1   10150  ...   1015000170701801104   202105
# 4         1   10150  ...   1015000170701801105   202105
# ...     ...     ...  ...                   ...      ...
# 30334     1  240352  ...  24035200010100507101   202105
# 30335     1  240352  ...  24035200010100507102   202105
# 30336     1  240352  ...  24035200010100507103   202105
# 30337     1  240352  ...  24035200010100507104   202105
# 30338     1  240352  ...  24035200010100507105   202105
#
# [30339 rows x 154 columns]

# %% [markdown]
# 2T2021 junio

# %%
path = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Ecuador/enemdu_persona_2021_06.csv'
df2T2021Bruto = pd.read_csv(path, delimiter=';')
df2T2021Bruto
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (154) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        area  ciudad  ...            id_persona  periodo
# 0         1   10150  ...   1015000020302203101   202106
# 1         1   10150  ...   1015000020302203102   202106
# 2         1   10150  ...   1015000020302204101   202106
# 3         1   10150  ...   1015000020302204102   202106
# 4         1   10150  ...   1015000020302206101   202106
# ...     ...     ...  ...                   ...      ...
# 30593     1  240352  ...  24035200300302410101   202106
# 30594     1  240352  ...  24035200300302410102   202106
# 30595     1  240352  ...  24035200300302410201   202106
# 30596     1  240352  ...  24035200300302410202   202106
# 30597     1  240352  ...  24035200300302410203   202106
#
# [30598 rows x 156 columns]
