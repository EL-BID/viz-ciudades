# %% [markdown]
# Fuente de los datos: <br>
# https://www.ine.cl/estadisticas/sociales/mercado-laboral/ocupacion-y-desocupacion <br>
# https://www.ine.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/libro-de-codigos/libro-de-c%C3%B3digos-base-ene-2021.pdf?sfvrsn=54753851_35

# %% [markdown]
# ##0. Preconfiguración y parámetros

# %%
import pandas as pd
pd.__version__

from google.colab import drive
drive.mount('/content/drive/')
# !ls
# Out:
# Mounted at /content/drive/
# drive  sample_data

# %% [markdown]
# ##1. Extracción de datos

# %% [markdown]
# 2017 segundo trimestre

# %%
path2017 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2017-06.csv'
df17_chi = pd.read_csv(path2017)
df17_chi
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd3 in position 6: unexpected end of data
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-4402fcc765ed> in <module>()
#       1 path2017 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2017-06.csv'
# ----> 2 df17_chi = pd.read_csv(path2017)
#       3 df17_chi
#
# ...

# %% [markdown]
# 2018 segundo trimestre

# %%
path2018 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2018-06.csv'
df18_chi = pd.read_csv(path2018)
df18_chi
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-b7236d0817ad> in <module>()
#       1 path2018 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2018-06.csv'
# ----> 2 df18_chi = pd.read_csv(path2018)
#       3 df18_chi
#
# ...

# %% [markdown]
# 2019 segundo trimestre

# %%
path2019 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2019-06.csv'
df19_chi = pd.read_csv(path2019)
df19_chi
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-214c836e6f43> in <module>()
#       1 path2019 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2019-06.csv'
# ----> 2 df19_chi = pd.read_csv(path2019)
#       3 df19_chi
#
# ...

# %% [markdown]
# 2020 segundo trimestre

# %%
path2020 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2020-06-mjj.csv'
df20_chi = pd.read_csv(path2020)
df20_chi
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-c8e43b067723> in <module>()
#       1 path2020 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2020-06-mjj.csv'
# ----> 2 df20_chi = pd.read_csv(path2020)
#       3 df20_chi
#
# ...

# %% [markdown]
# 2021 segundo trimestre

# %%
path2021 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2021-06-mjj.csv'
df21_chi = pd.read_csv(path2021)
df21_chi
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-f2382abb4993> in <module>()
#       1 path2021 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Chile/ene-2021-06-mjj.csv'
# ----> 2 df21_chi = pd.read_csv(path2021)
#       3 df21_chi
#
# ...

# %% [markdown]
# ##2. Depuración

# %% [markdown]
# ##3. Limpieza

# %% [markdown]
# ##4. Guardando la gran tabla para Chile
