# %% [markdown]
# ##0. Preconfiguración

# %%
import pandas as pd
pd.__version__

from google.colab import drive
drive.mount('/content/drive/')
# !ls
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# drive  sample_data

# %%
pip install pyreadstat

# %%
# %cd'/content/drive/My Drive/BID Ciudades/MicroDatos/Peru'
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/BID Ciudades/MicroDatos/Peru'
# /content
# drive  sample_data

# %% [markdown]
# ##1. Extracción de datos

# %% [markdown]
# 2017 T2

# %%
path1 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Perú/Trim Abr-May-Jun17.sav'
df1_peru2017 = pd.read_spss(path1)
df1_peru2017
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-34cf222e66c2> in <module>()
#       1 path1 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Perú/Trim Abr-May-Jun17.sav'
# ----> 2 df1_peru2017 = pd.read_spss(path1)
#       3 df1_peru2017
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/spss.py in read_spss(path, usecols, convert_categoricals)
#      34     Returns
#      35     -------
# ---> 36     DataFrame
#      37     """
#      38     pyreadstat = import_optional_dependency("pyreadstat")
#
# /usr/local/lib/python3.7/dist-packages/pandas/compat/_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)
#     105     assert errors in {"warn", "raise", "ignore"}
#     106
# --> 107     package_name = INSTALL_MAPPING.get(name)
#     108     install_name = package_name if package_name is not None else name
#     109
#
# ...

# %% [markdown]
# 2021 T2

# %%
path1 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/Perú/Trim Abr-May-Jun21.csv'
df1_peru2021 = pd.read_csv(path1)
df1_peru2021
# Out:
#        pano  pmes  conglome  ...  ingprin  resident          fa_amj21
# 0      2021     4     17253  ...                  1  312.510131922938
# 1      2021     4     17253  ...      650         1  324.996111552785
# 2      2021     4     17253  ...      930         1  414.015253177853
# 3      2021     4     17253  ...                  1   442.83943679445
# 4      2021     4     17253  ...                  1
# ...     ...   ...       ...  ...      ...       ...               ...
# 15654  2021     6     90437  ...    14500         1    791.6518231999
# 15655  2021     6     26450  ...     8500         1  197.415571362873
# 15656  2021     6     18452  ...    16500         1  178.849718683001
# 15657  2021     6     26411  ...    16500         1  151.864872365363
# 15658  2021     6     90305  ...    31500         1  269.676032313239
#
# [15659 rows x 103 columns]
# ...

# %%
df1_peru2021['dominio'].value_counts()
# Out:
# 8    15659
# Name: dominio, dtype: int64

# %% [markdown]
# ##Parámetros Diccionarios Perú

# %% [markdown]
# http://iinei.inei.gob.pe/iinei/srienaho/Descarga/DocumentosMetodologicos/2017-39/Diccionario.pdf

# %% [markdown]
# OCU200 1 0 N Indicador de condición de actividad
#  1 Ocupado
# 2 Desocupado abierto
# 3 Desocupado oculto
# 4 No PEA
#
# P201 1 0 N La semana pasada del...al...,¿Tuvo Ud.algún trabajó?
#  1 Sí
#  2 No
#  9 Missing value
# rango:
# 1 2

# %% [markdown]
# P205A 4 0 N A qué se dedica el negocio, organismo o empresa en la que
# trabajó en su ocupación principal?
# Rama de actividad económica abierta a 4 dígitos
# (Desde Marzo del 2002)
#  9999 Missing Value
#
#  P205 2 0 N A qué se dedica el negocio, organismo o empresa en la que
# trabajó en su ocupación principal?
# Rama de actividad económica cerrada: Precodificada
# (Desde Marzo del 2001 hasta Febrero del 2003)
#  1 Agricultura/Pesca/Minería
# 2 Manufactura
# 3 Construcción
# 4 Comercio
# 5 Restaurantes y Hoteles
# 6 Transportes y comunicaciones
# 7 Otros servicios (Sector Público,bancos,salud,educación,etc)
#  rango:
#  1 7

# %% [markdown]
# INGTOT 8 0 N Total ingreso mensual (Ingreso Total por Trabajo) por persona
# (Desde Setiembre del 2001)
#
#
# INGPRIN 8 0 N Total ingreso mensual (Ingreso Principal por Trabajo) por
# persona
#
# P211A 6 0 N Cuál fue su ingreso total monetario en la ocupación principal
# por trab. dependiente
# (Pregunta: P211)
#  999999 Missing value
#
#  P212A 6 0 N Cuál fue su ingreso total monetario en la ocupación principal
# por trab. Independiente
# (Pregunta: P212)
#  999999 Missing value
# P212B 6 0 N Cuál fue su ingreso en especie en la ocupación principal por
# trab. Independiente
# (Pregunta: P212)

# %% [markdown]
# DOMINIO 1 0 N Dominio
# 8 Lima Metropolitana
#  rango:
# 1

# %% [markdown]
# ##2. Transformación de los datos

# %% [markdown]
# ##3. Limpieza de datos
