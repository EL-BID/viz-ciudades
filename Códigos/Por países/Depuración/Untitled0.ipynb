# %%
import pandas as pd
pd.__version__

from google.colab import drive
drive.mount('/content/drive/')
# !ls
# Out:
# Mounted at /content/drive/
# drive  sample_data

# %%
# %cd'/content/drive/My Drive/BID Ciudades/MicroDatos'
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/BID Ciudades/MicroDatos'
# /content
# drive  sample_data

# %% [markdown]
# Base 2EMP

# %%
path1 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/EMP_2EMP_SEX_GEO_ECO_NB_A-filtered-2022-01-21.csv'
df1_caribe = pd.read_csv(path1)
df1_caribe
# Out:
#                    ref_area.label  ... obs_status.label
# 0                         Bahamas  ...              NaN
# 1                         Bahamas  ...              NaN
# 2                         Bahamas  ...              NaN
# 3                         Bahamas  ...              NaN
# 4                         Bahamas  ...              NaN
# ..                            ...  ...              ...
# 163  United States Virgin Islands  ...              NaN
# 164  United States Virgin Islands  ...              NaN
# 165  United States Virgin Islands  ...              NaN
# 166  United States Virgin Islands  ...              NaN
# 167  United States Virgin Islands  ...              NaN
#
# [168 rows x 9 columns]

# %% [markdown]
# Base TEMP

# %%
path1 = '/content/drive/Shareddrives/BID/Ciudades/MicroDatos/EMP_TEMP_SEX_ECO_GEO_NB_A-filtered-2022-01-21.csv'
df1_caribe = pd.read_csv(path1)
df1_caribe
# Out:
#     ref_area.label  ...                                  note_source.label
# 0           Belize  ...  Repository: ILO-STATISTICS - Micro data proces...
# 1           Belize  ...  Repository: ILO-STATISTICS - Micro data proces...
# 2           Belize  ...  Repository: ILO-STATISTICS - Micro data proces...
# 3           Belize  ...  Repository: ILO-STATISTICS - Micro data proces...
# 4           Belize  ...  Repository: ILO-STATISTICS - Micro data proces...
# ..             ...  ...                                                ...
# 127        Jamaica  ...  Repository: ILO-STATISTICS - Micro data proces...
# 128        Jamaica  ...  Repository: ILO-STATISTICS - Micro data proces...
# 129        Jamaica  ...  Repository: ILO-STATISTICS - Micro data proces...
# 130        Jamaica  ...  Repository: ILO-STATISTICS - Micro data proces...
# 131        Jamaica  ...  Repository: ILO-STATISTICS - Micro data proces...
#
# [132 rows x 11 columns]
